# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# done
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# done
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 606

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# done
# Set the API base URL
base_url=f'https://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}'
# Define an empty list to fetch the weather data for each city
city_data = []
# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
#     if i>15:break #<-------------------------------------------------------test
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
    # Create endpoint URL with each city
    city_url = f'{base_url}&q={city}'    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    # Add 1 to the record count
    record_count += 1
    
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        response=requests.get(city_url)
        responsej=response.json()
#         pprint(responsej)

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat=responsej['coord']['lat']
        city_lng=responsej['coord']['lon']
#         print(city_lat,city_lng)
        #       
        city_max_temp=responsej['main']['temp_max']
        city_humidity=responsej['main']['humidity']
        city_clouds=responsej['clouds']['all']
        city_wind=responsej['wind']['speed']
        city_country=responsej['sys']['country']
        city_date=responsej['dt']
        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

#         break
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | chhota udepur
# {'base': 'stations',
#  'clouds': {'all': 30},
#  'cod': 200,
#  'coord': {'lat': 22.3167, 'lon': 74.0167},
#  'dt': 1681949220,
#  'id': 1274285,
#  'main': {'feels_like': 299.71,
#           'grnd_level': 989,
#           'humidity': 32,
#           'pressure': 1006,
#           'sea_level': 1006,
#           'temp': 300.25,
#           'temp_max': 300.25,
#           'temp_min': 300.25},
#  'name': 'Chhota Udepur',
#  'sys': {'country': 'IN', 'sunrise': 1681951212, 'sunset': 1681997120},
#  'timezone': 19800,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 291, 'gust': 1.43, 'speed': 1.27}}
# 22.3167 74.0167
# Processing Record 2 of Set 1 | rosarno
# {'base': 'stations',
#  'clouds': {'all': 37},
#  'cod': 200,
#  'coord': {'lat': 38.4841, 'lon': 15.979},
#  'dt': 1681949220,
#  'id': 2523585,
#  'main': {'feels_like': 284.98,
#           'grnd_level': 1008,
#           'humidity': 72,
#           'pressure': 1015,
#           'sea_level': 1015,
#           'temp': 285.78,
#           'temp_max': 286.71,
#           'temp_min': 284.76},
#  'name': 'Rosarno',
#  'sys': {'country': 'IT',
#          'id': 2004206,
#          'sunrise': 1681964016,
#          'sunset': 1682012170,
#          'type': 2},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 102, 'gust': 2.32, 'speed': 2.32}}
# 38.4841 15.979
# Processing Record 3 of Set 1 | grytviken
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -54.2811, 'lon': -36.5092},
#  'dt': 1681949016,
#  'id': 3426466,
#  'main': {'feels_like': 275.32,
#           'grnd_level': 988,
#           'humidity': 95,
#           'pressure': 993,
#           'sea_level': 993,
#           'temp': 276.82,
#           'temp_max': 276.82,
#           'temp_min': 276.82},
#  'name': 'Grytviken',
#  'sys': {'country': 'GS', 'sunrise': 1681896142, 'sunset': 1681932460},
#  'timezone': -7200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 277, 'gust': 2.08, 'speed': 1.7}}
# -54.2811 -36.5092
# Processing Record 4 of Set 1 | waitangi
# {'base': 'stations',
#  'clouds': {'all': 94},
#  'cod': 200,
#  'coord': {'lat': -43.9535, 'lon': -176.5597},
#  'dt': 1681949012,
#  'id': 4032804,
#  'main': {'feels_like': 290.98,
#           'humidity': 89,
#           'pressure': 1026,
#           'temp': 290.83,
#           'temp_max': 290.83,
#           'temp_min': 290.83},
#  'name': 'Waitangi',
#  'sys': {'country': 'NZ',
#          'id': 2040615,
#          'sunrise': 1682015143,
#          'sunset': 1682053448,
#          'type': 2},
#  'timezone': 45900,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 264, 'gust': 9.83, 'speed': 4.02}}
# -43.9535 -176.5597
# Processing Record 5 of Set 1 | adamstown
# {'base': 'stations',
#  'clouds': {'all': 96},
#  'cod': 200,
#  'coord': {'lat': -25.066, 'lon': -130.1015},
#  'dt': 1681949007,
#  'id': 4030723,
#  'main': {'feels_like': 298.04,
#           'grnd_level': 1003,
#           'humidity': 76,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 297.56,
#           'temp_max': 297.56,
#           'temp_min': 297.56},
#  'name': 'Adamstown',
#  'rain': {'1h': 0.15},
#  'sys': {'country': 'PN', 'sunrise': 1681916209, 'sunset': 1681957310},
#  'timezone': -28800,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 356, 'gust': 1.04, 'speed': 0.87}}
# -25.066 -130.1015
# Processing Record 6 of Set 1 | santa ana
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 33.7456, 'lon': -117.8678},
#  'dt': 1681949215,
#  'id': 5392900,
#  'main': {'feels_like': 291.6,
#           'humidity': 47,
#           'pressure': 1016,
#           'temp': 292.39,
#           'temp_max': 296.15,
#           'temp_min': 288.49},
#  'name': 'Santa Ana',
#  'sys': {'country': 'US',
#          'id': 2003506,
#          'sunrise': 1681910156,
#          'sunset': 1681957492,
#          'type': 2},
#  'timezone': -25200,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 240, 'speed': 6.17}}
# 33.7456 -117.8678
# Processing Record 7 of Set 1 | puerto aysen
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -45.4, 'lon': -72.7},
#  'dt': 1681949223,
#  'id': 3874997,
#  'main': {'feels_like': 285.53,
#           'grnd_level': 1017,
#           'humidity': 99,
#           'pressure': 1017,
#           'sea_level': 1017,
#           'temp': 285.64,
#           'temp_max': 285.64,
#           'temp_min': 285.64},
#  'name': 'Puerto Aisén',
#  'sys': {'country': 'CL', 'sunrise': 1681903855, 'sunset': 1681942116},
#  'timezone': -14400,
#  'visibility': 126,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 302, 'gust': 3.4, 'speed': 1.98}}
# -45.4 -72.7
# Processing Record 8 of Set 1 | salinas
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 36.6777, 'lon': -121.6555},
#  'dt': 1681949166,
#  'id': 5391295,
#  'main': {'feels_like': 287,
#           'humidity': 56,
#           'pressure': 1023,
#           'temp': 288,
#           'temp_max': 293.14,
#           'temp_min': 285.42},
#  'name': 'Salinas',
#  'sys': {'country': 'US',
#          'id': 5885,
#          'sunrise': 1681910844,
#          'sunset': 1681958622,
#          'type': 1},
#  'timezone': -25200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 260, 'speed': 6.17}}
# 36.6777 -121.6555
# Processing Record 9 of Set 1 | greenville
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 35.6127, 'lon': -77.3663},
#  'dt': 1681949224,
#  'id': 4469160,
#  'main': {'feels_like': 295.88,
#           'humidity': 50,
#           'pressure': 1020,
#           'temp': 296.21,
#           'temp_max': 296.55,
#           'temp_min': 294.17},
#  'name': 'Greenville',
#  'sys': {'country': 'US',
#          'id': 5345,
#          'sunrise': 1681900306,
#          'sunset': 1681947904,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 0, 'speed': 0}}
# 35.6127 -77.3663
# Processing Record 10 of Set 1 | port-aux-francais
# {'base': 'stations',
#  'clouds': {'all': 18},
#  'cod': 200,
#  'coord': {'lat': -49.35, 'lon': 70.2167},
#  'dt': 1681948984,
#  'id': 1546102,
#  'main': {'feels_like': 271.3,
#           'grnd_level': 1003,
#           'humidity': 68,
#           'pressure': 1004,
#           'sea_level': 1004,
#           'temp': 277.98,
#           'temp_max': 277.98,
#           'temp_min': 277.98},
#  'name': 'Port-aux-Français',
#  'sys': {'country': 'TF', 'sunrise': 1681956401, 'sunset': 1681993754},
#  'timezone': 18000,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 258, 'gust': 18.69, 'speed': 15.5}}
# -49.35 70.2167
# Processing Record 11 of Set 1 | ilulissat
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 69.2167, 'lon': -51.1},
#  'dt': 1681948991,
#  'id': 3423146,
#  'main': {'feels_like': 265.63,
#           'humidity': 80,
#           'pressure': 1034,
#           'temp': 268.16,
#           'temp_max': 268.16,
#           'temp_min': 268.16},
#  'name': 'Ilulissat',
#  'sys': {'country': 'GL',
#          'id': 165,
#          'sunrise': 1681888039,
#          'sunset': 1681947565,
#          'type': 1},
#  'timezone': -7200,
#  'visibility': 10000,
#  'weather': [{'description': 'light snow',
#               'icon': '13n',
#               'id': 600,
#               'main': 'Snow'}],
#  'wind': {'deg': 300, 'speed': 1.54}}
# 69.2167 -51.1
# Processing Record 12 of Set 1 | port lincoln
# {'base': 'stations',
#  'clouds': {'all': 94},
#  'cod': 200,
#  'coord': {'lat': -34.7333, 'lon': 135.8667},
#  'dt': 1681949226,
#  'id': 2063036,
#  'main': {'feels_like': 288.91,
#           'grnd_level': 1027,
#           'humidity': 57,
#           'pressure': 1029,
#           'sea_level': 1029,
#           'temp': 289.71,
#           'temp_max': 289.71,
#           'temp_min': 289.71},
#  'name': 'Port Lincoln',
#  'sys': {'country': 'AU', 'sunrise': 1681939383, 'sunset': 1681979265},
#  'timezone': 34200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 252, 'gust': 3.12, 'speed': 2.93}}
# -34.7333 135.8667
# Processing Record 13 of Set 1 | lompoc
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 34.6391, 'lon': -120.4579},
#  'dt': 1681949028,
#  'id': 5367788,
#  'main': {'feels_like': 287.75,
#           'humidity': 64,
#           'pressure': 1018,
#           'temp': 288.49,
#           'temp_max': 295.81,
#           'temp_min': 284.77},
#  'name': 'Lompoc',
#  'sys': {'country': 'US',
#          'id': 2005037,
#          'sunrise': 1681910712,
#          'sunset': 1681958179,
#          'type': 2},
#  'timezone': -25200,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 328, 'gust': 14.31, 'speed': 11.18}}
# 34.6391 -120.4579
# Processing Record 14 of Set 1 | bilibino
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 68.0546, 'lon': 166.4372},
#  'dt': 1681949037,
#  'id': 2126682,
#  'main': {'feels_like': 270.16,
#           'grnd_level': 982,
#           'humidity': 84,
#           'pressure': 1017,
#           'sea_level': 1017,
#           'temp': 271.96,
#           'temp_max': 271.96,
#           'temp_min': 271.96},
#  'name': 'Bilibino',
#  'sys': {'country': 'RU', 'sunrise': 1681922652, 'sunset': 1681981324},
#  'timezone': 43200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 114, 'gust': 1.66, 'speed': 1.43}}
# 68.0546 166.4372
# Processing Record 15 of Set 1 | taiohae
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 16 of Set 1 | gallivare
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 17 of Set 1 | las margaritas
# {'base': 'stations',
#  'clouds': {'all': 72},
#  'cod': 200,
#  'coord': {'lat': 16.3167, 'lon': -91.9833},
#  'dt': 1681949229,
#  'id': 3524744,
#  'main': {'feels_like': 296.13,
#           'grnd_level': 851,
#           'humidity': 40,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 296.68,
#           'temp_max': 296.68,
#           'temp_min': 296.68},
#  'name': 'Las Margaritas',
#  'sys': {'country': 'MX', 'sunrise': 1681905006, 'sunset': 1681950219},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 68, 'gust': 8.74, 'speed': 5.19}}
# 16.3167 -91.9833
# Processing Record 18 of Set 1 | tiksi
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 71.6872, 'lon': 128.8694},
#  'dt': 1681948986,
#  'id': 2015306,
#  'main': {'feels_like': 247.08,
#           'grnd_level': 1018,
#           'humidity': 99,
#           'pressure': 1023,
#           'sea_level': 1023,
#           'temp': 252.95,
#           'temp_max': 252.95,
#           'temp_min': 252.95},
#  'name': 'Tiksi',
#  'sys': {'country': 'RU', 'sunrise': 1681929669, 'sunset': 1681992337},
#  'timezone': 32400,
#  'visibility': 2097,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 68, 'gust': 2.41, 'speed': 2.04}}
# 71.6872 128.8694
# Processing Record 19 of Set 1 | vorgashor
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 67.5833, 'lon': 63.95},
#  'dt': 1681949041,
#  'id': 1486913,
#  'main': {'feels_like': 260.05,
#           'grnd_level': 995,
#           'humidity': 97,
#           'pressure': 1018,
#           'sea_level': 1018,
#           'temp': 265.73,
#           'temp_max': 265.73,
#           'temp_min': 265.73},
#  'name': 'Vorgashor',
#  'sys': {'country': 'RU', 'sunrise': 1681947374, 'sunset': 1682005789},
#  'timezone': 10800,
#  'visibility': 866,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 183, 'gust': 6.87, 'speed': 3.67}}
# 67.5833 63.95
# Processing Record 20 of Set 1 | georgetown
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 5.4112, 'lon': 100.3354},
#  'dt': 1681949129,
#  'id': 1735106,
#  'main': {'feels_like': 299.17,
#           'humidity': 94,
#           'pressure': 1007,
#           'temp': 298.16,
#           'temp_max': 299.11,
#           'temp_min': 298.12},
#  'name': 'George Town',
#  'rain': {'1h': 3.16},
#  'sys': {'country': 'MY',
#          'id': 49151,
#          'sunrise': 1681945785,
#          'sunset': 1681989915,
#          'type': 2},
#  'timezone': 28800,
#  'visibility': 5000,
#  'weather': [{'description': 'thunderstorm with light rain',
#               'icon': '11d',
#               'id': 200,
#               'main': 'Thunderstorm'},
#              {'description': 'moderate rain',
#               'icon': '10d',
#               'id': 501,
#               'main': 'Rain'}],
#  'wind': {'deg': 170, 'gust': 0, 'speed': 2.68}}
# 5.4112 100.3354
# Processing Record 21 of Set 1 | kapuskasing
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 49.4169, 'lon': -82.4331},
#  'dt': 1681949232,
#  'id': 5989403,
#  'main': {'feels_like': 267.8,
#           'grnd_level': 995,
#           'humidity': 88,
#           'pressure': 1022,
#           'sea_level': 1022,
#           'temp': 272.05,
#           'temp_max': 272.05,
#           'temp_min': 272.05},
#  'name': 'Kapuskasing',
#  'sys': {'country': 'CA', 'sunrise': 1681900207, 'sunset': 1681950434},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 312, 'gust': 8.62, 'speed': 3.62}}
# 49.4169 -82.4331
# Processing Record 22 of Set 1 | blackmans bay
# {'base': 'stations',
#  'clouds': {'all': 97},
#  'cod': 200,
#  'coord': {'lat': -43.0167, 'lon': 147.3167},
#  'dt': 1681948999,
#  'id': 2175527,
#  'main': {'feels_like': 286.22,
#           'humidity': 77,
#           'pressure': 1014,
#           'temp': 286.79,
#           'temp_max': 287.44,
#           'temp_min': 283},
#  'name': 'Blackmans Bay',
#  'sys': {'country': 'AU',
#          'id': 2011256,
#          'sunrise': 1681937266,
#          'sunset': 1681975886,
#          'type': 2},
#  'timezone': 36000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 323, 'gust': 8.29, 'speed': 3.29}}
# -43.0167 147.3167
# Processing Record 23 of Set 1 | port-cartier
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 50.0334, 'lon': -66.8654},
#  'dt': 1681949233,
#  'id': 6111696,
#  'main': {'feels_like': 274.68,
#           'grnd_level': 1007,
#           'humidity': 97,
#           'pressure': 1010,
#           'sea_level': 1010,
#           'temp': 274.68,
#           'temp_max': 274.68,
#           'temp_min': 274.27},
#  'name': 'Port-Cartier',
#  'snow': {'1h': 1.54},
#  'sys': {'country': 'CA',
#          'id': 2006302,
#          'sunrise': 1681896400,
#          'sunset': 1681946770,
#          'type': 2},
#  'timezone': -14400,
#  'visibility': 3182,
#  'weather': [{'description': 'snow', 'icon': '13n', 'id': 601, 'main': 'Snow'}],
#  'wind': {'deg': 304, 'gust': 0.97, 'speed': 0.72}}
# 50.0334 -66.8654
# Processing Record 24 of Set 1 | invercargill
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': -46.4, 'lon': 168.35},
#  'dt': 1681949015,
#  'id': 2189529,
#  'main': {'feels_like': 287.2,
#           'grnd_level': 1019,
#           'humidity': 69,
#           'pressure': 1020,
#           'sea_level': 1020,
#           'temp': 287.87,
#           'temp_max': 287.87,
#           'temp_min': 287.87},
#  'name': 'Invercargill',
#  'sys': {'country': 'NZ', 'sunrise': 1681932523, 'sunset': 1681970536},
#  'timezone': 43200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 355, 'gust': 3.02, 'speed': 1.79}}
# -46.4 168.35
# Processing Record 25 of Set 1 | olonkinbyen
# {'base': 'stations',
#  'clouds': {'all': 58},
#  'cod': 200,
#  'coord': {'lat': 70.9221, 'lon': -8.7187},
#  'dt': 1681949041,
#  'id': 7535941,
#  'main': {'feels_like': 268.93,
#           'grnd_level': 1023,
#           'humidity': 87,
#           'pressure': 1025,
#           'sea_level': 1025,
#           'temp': 275.47,
#           'temp_max': 275.47,
#           'temp_min': 275.47},
#  'name': 'Olonkinbyen',
#  'sys': {'country': 'SJ', 'sunrise': 1681963059, 'sunset': 1682024980},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 232, 'gust': 18.75, 'speed': 10.9}}
# 70.9221 -8.7187
# Processing Record 26 of Set 1 | udachny
# {'base': 'stations',
#  'clouds': {'all': 99},
#  'cod': 200,
#  'coord': {'lat': 66.4167, 'lon': 112.4},
#  'dt': 1681949179,
#  'id': 2014624,
#  'main': {'feels_like': 258.2,
#           'grnd_level': 981,
#           'humidity': 72,
#           'pressure': 1018,
#           'sea_level': 1018,
#           'temp': 262.29,
#           'temp_max': 262.29,
#           'temp_min': 262.29},
#  'name': 'Udachny',
#  'sys': {'country': 'RU',
#          'id': 49565,
#          'sunrise': 1681936236,
#          'sunset': 1681993674,
#          'type': 2},
#  'timezone': 32400,
#  'visibility': 3595,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 318, 'gust': 2.12, 'speed': 1.91}}
# 66.4167 112.4
# Processing Record 27 of Set 1 | vega de alatorre
# {'base': 'stations',
#  'clouds': {'all': 60},
#  'cod': 200,
#  'coord': {'lat': 20.0333, 'lon': -96.6333},
#  'dt': 1681949235,
#  'id': 3514843,
#  'main': {'feels_like': 299.61,
#           'grnd_level': 1007,
#           'humidity': 85,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 299.61,
#           'temp_max': 299.61,
#           'temp_min': 299.61},
#  'name': 'Vega de Alatorre',
#  'sys': {'country': 'MX', 'sunrise': 1681905921, 'sunset': 1681951535},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 96, 'gust': 4.12, 'speed': 3.12}}
# 20.0333 -96.6333
# Processing Record 28 of Set 1 | namibe
# {'base': 'stations',
#  'clouds': {'all': 73},
#  'cod': 200,
#  'coord': {'lat': -15.1961, 'lon': 12.1522},
#  'dt': 1681949024,
#  'id': 3347019,
#  'main': {'feels_like': 298.81,
#           'grnd_level': 1007,
#           'humidity': 74,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 298.31,
#           'temp_max': 298.31,
#           'temp_min': 298.31},
#  'name': 'Mossamedes',
#  'rain': {'1h': 0.23},
#  'sys': {'country': 'AO', 'sunrise': 1681967954, 'sunset': 1682010068},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 307, 'gust': 2.03, 'speed': 1.94}}
# -15.1961 12.1522
# Processing Record 29 of Set 1 | chonchi
# {'base': 'stations',
#  'clouds': {'all': 95},
#  'cod': 200,
#  'coord': {'lat': -42.6128, 'lon': -73.8092},
#  'dt': 1681949237,
#  'id': 3894871,
#  'main': {'feels_like': 286.53,
#           'grnd_level': 1009,
#           'humidity': 99,
#           'pressure': 1018,
#           'sea_level': 1018,
#           'temp': 286.55,
#           'temp_max': 286.71,
#           'temp_min': 286.55},
#  'name': 'Chonchi',
#  'sys': {'country': 'CL',
#          'id': 2043794,
#          'sunrise': 1681903876,
#          'sunset': 1681942627,
#          'type': 2},
#  'timezone': -14400,
#  'visibility': 8230,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 227, 'gust': 0.9, 'speed': 0.8}}
# -42.6128 -73.8092
# Processing Record 30 of Set 1 | west island
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -12.1568, 'lon': 96.8225},
#  'dt': 1681949017,
#  'id': 7304591,
#  'main': {'feels_like': 299.14,
#           'humidity': 94,
#           'pressure': 1009,
#           'temp': 299.14,
#           'temp_max': 299.14,
#           'temp_min': 299.14},
#  'name': 'West Island',
#  'sys': {'country': 'CC',
#          'id': 9570,
#          'sunrise': 1681947478,
#          'sunset': 1681989908,
#          'type': 1},
#  'timezone': 23400,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 120, 'speed': 5.66}}
# -12.1568 96.8225
# Processing Record 31 of Set 1 | san antonio de pale
# {'base': 'stations',
#  'clouds': {'all': 99},
#  'cod': 200,
#  'coord': {'lat': -1.4014, 'lon': 5.6325},
#  'dt': 1681949121,
#  'id': 2306774,
#  'main': {'feels_like': 306.09,
#           'grnd_level': 1009,
#           'humidity': 82,
#           'pressure': 1009,
#           'sea_level': 1009,
#           'temp': 301.35,
#           'temp_max': 301.35,
#           'temp_min': 301.35},
#  'name': 'San Antonio de Palé',
#  'rain': {'1h': 1.05},
#  'sys': {'country': 'GQ', 'sunrise': 1681968840, 'sunset': 1682012311},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'moderate rain',
#               'icon': '10n',
#               'id': 501,
#               'main': 'Rain'}],
#  'wind': {'deg': 177, 'gust': 4.83, 'speed': 4.32}}
# -1.4014 5.6325
# Processing Record 32 of Set 1 | bredasdorp
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -34.5322, 'lon': 20.0403},
#  'dt': 1681949026,
#  'id': 1015776,
#  'main': {'feels_like': 288.84,
#           'grnd_level': 997,
#           'humidity': 67,
#           'pressure': 1006,
#           'sea_level': 1006,
#           'temp': 289.41,
#           'temp_max': 289.41,
#           'temp_min': 289.41},
#  'name': 'Bredasdorp',
#  'sys': {'country': 'ZA', 'sunrise': 1681967183, 'sunset': 1682007054},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 354, 'gust': 2.18, 'speed': 2.12}}
# -34.5322 20.0403
# Processing Record 33 of Set 1 | margaret river
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -33.95, 'lon': 115.0667},
#  'dt': 1681949006,
#  'id': 2066981,
#  'main': {'feels_like': 286.37,
#           'grnd_level': 1014,
#           'humidity': 57,
#           'pressure': 1024,
#           'sea_level': 1024,
#           'temp': 287.4,
#           'temp_max': 287.4,
#           'temp_min': 287.4},
#  'name': 'Margaret River',
#  'sys': {'country': 'AU', 'sunrise': 1681944324, 'sunset': 1681984306},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 52, 'gust': 6.72, 'speed': 3.55}}
# -33.95 115.0667
# Processing Record 34 of Set 1 | talnakh
# {'base': 'stations',
#  'clouds': {'all': 95},
#  'cod': 200,
#  'coord': {'lat': 69.4865, 'lon': 88.3972},
#  'dt': 1681949105,
#  'id': 1490256,
#  'main': {'feels_like': 252.04,
#           'grnd_level': 1012,
#           'humidity': 96,
#           'pressure': 1021,
#           'sea_level': 1021,
#           'temp': 258.82,
#           'temp_max': 258.82,
#           'temp_min': 258.82},
#  'name': 'Talnakh',
#  'sys': {'country': 'RU',
#          'id': 49144,
#          'sunrise': 1681940647,
#          'sunset': 1682000783,
#          'type': 2},
#  'timezone': 25200,
#  'visibility': 6427,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 130, 'gust': 3.79, 'speed': 3.31}}
# 69.4865 88.3972
# Processing Record 35 of Set 1 | iqaluit
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 63.7506, 'lon': -68.5145},
#  'dt': 1681948923,
#  'id': 5983720,
#  'main': {'feels_like': 265.76,
#           'humidity': 85,
#           'pressure': 1026,
#           'temp': 265.76,
#           'temp_max': 266,
#           'temp_min': 265.76},
#  'name': 'Iqaluit',
#  'snow': {'1h': 0.45},
#  'sys': {'country': 'CA',
#          'id': 47658,
#          'sunrise': 1681894231,
#          'sunset': 1681949731,
#          'type': 2},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'light snow',
#               'icon': '13d',
#               'id': 600,
#               'main': 'Snow'}],
#  'wind': {'deg': 0, 'speed': 0}}
# 63.7506 -68.5145
# Processing Record 36 of Set 1 | alofi
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -19.0595, 'lon': -169.9187},
#  'dt': 1681949241,
#  'id': 4036284,
#  'main': {'feels_like': 299.58,
#           'grnd_level': 997,
#           'humidity': 78,
#           'pressure': 1005,
#           'sea_level': 1005,
#           'temp': 299.58,
#           'temp_max': 299.58,
#           'temp_min': 299.58},
#  'name': 'Alofi',
#  'rain': {'1h': 0.1},
#  'sys': {'country': 'NU', 'sunrise': 1681925443, 'sunset': 1681967186},
#  'timezone': -39600,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 165, 'gust': 3.84, 'speed': 2.33}}
# -19.0595 -169.9187
# Processing Record 37 of Set 1 | papatowai
# {'base': 'stations',
#  'clouds': {'all': 63},
#  'cod': 200,
#  'coord': {'lat': -46.5619, 'lon': 169.4708},
#  'dt': 1681949020,
#  'id': 2185172,
#  'main': {'feels_like': 287.72,
#           'grnd_level': 1016,
#           'humidity': 69,
#           'pressure': 1020,
#           'sea_level': 1020,
#           'temp': 288.34,
#           'temp_max': 288.34,
#           'temp_min': 288.34},
#  'name': 'Papatowai',
#  'sys': {'country': 'NZ', 'sunrise': 1681932269, 'sunset': 1681970251},
#  'timezone': 43200,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 42, 'gust': 2.09, 'speed': 0.51}}
# -46.5619 169.4708
# Processing Record 38 of Set 1 | constantia
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 44.1833, 'lon': 28.65},
#  'dt': 1681949243,
#  'id': 680963,
#  'main': {'feels_like': 283.08,
#           'grnd_level': 1005,
#           'humidity': 94,
#           'pressure': 1010,
#           'sea_level': 1010,
#           'temp': 283.53,
#           'temp_max': 283.54,
#           'temp_min': 283.53},
#  'name': 'Constanța',
#  'rain': {'1h': 0.15},
#  'sys': {'country': 'RO',
#          'id': 6912,
#          'sunrise': 1681960454,
#          'sunset': 1682009651,
#          'type': 1},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 304, 'gust': 9.14, 'speed': 5.86}}
# 44.1833 28.65
# Processing Record 39 of Set 1 | cat ba
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 40 of Set 1 | waddan
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 29.1614, 'lon': 16.139},
#  'dt': 1681949245,
#  'id': 2209055,
#  'main': {'feels_like': 292.4,
#           'grnd_level': 985,
#           'humidity': 24,
#           'pressure': 1014,
#           'sea_level': 1014,
#           'temp': 293.67,
#           'temp_max': 293.67,
#           'temp_min': 293.67},
#  'name': 'Waddān',
#  'sys': {'country': 'LY', 'sunrise': 1681964670, 'sunset': 1682011439},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 143, 'gust': 9.18, 'speed': 5.36}}
# 29.1614 16.139
# Processing Record 41 of Set 1 | ancud
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': -41.8697, 'lon': -73.8203},
#  'dt': 1681949246,
#  'id': 3899695,
#  'main': {'feels_like': 285.64,
#           'grnd_level': 1012,
#           'humidity': 96,
#           'pressure': 1018,
#           'sea_level': 1018,
#           'temp': 285.81,
#           'temp_max': 285.81,
#           'temp_min': 285.81},
#  'name': 'Ancud',
#  'sys': {'country': 'CL', 'sunrise': 1681903817, 'sunset': 1681942691},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 125, 'gust': 3.36, 'speed': 1.93}}
# -41.8697 -73.8203
# Processing Record 42 of Set 1 | san sebastian de la gomera
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 28.0916, 'lon': -17.1133},
#  'dt': 1681949246,
#  'id': 2511230,
#  'main': {'feels_like': 292.22,
#           'humidity': 72,
#           'pressure': 1017,
#           'temp': 292.36,
#           'temp_max': 292.8,
#           'temp_min': 290.46},
#  'name': 'San Sebastián de La Gomera',
#  'sys': {'country': 'ES',
#          'id': 2372,
#          'sunrise': 1681972715,
#          'sunset': 1682019353,
#          'type': 1},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 0, 'speed': 1.03}}
# 28.0916 -17.1133
# Processing Record 43 of Set 1 | tamanrasset
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 22.785, 'lon': 5.5228},
#  'dt': 1681949247,
#  'id': 2478216,
#  'main': {'feels_like': 291.46,
#           'humidity': 12,
#           'pressure': 1020,
#           'temp': 293.1,
#           'temp_max': 293.1,
#           'temp_min': 293.1},
#  'name': 'Tamanghasset',
#  'sys': {'country': 'DZ',
#          'id': 1066,
#          'sunrise': 1681967614,
#          'sunset': 1682013590,
#          'type': 1},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 0, 'speed': 0}}
# 22.785 5.5228
# Processing Record 44 of Set 1 | ribeira grande
# {'base': 'stations',
#  'clouds': {'all': 70},
#  'cod': 200,
#  'coord': {'lat': 38.5167, 'lon': -28.7},
#  'dt': 1681949067,
#  'id': 3372707,
#  'main': {'feels_like': 284.42,
#           'humidity': 73,
#           'pressure': 1010,
#           'temp': 285.25,
#           'temp_max': 285.25,
#           'temp_min': 285.25},
#  'name': 'Ribeira Grande',
#  'sys': {'country': 'PT',
#          'id': 2078208,
#          'sunrise': 1681974726,
#          'sunset': 1682022903,
#          'type': 2},
#  'timezone': 0,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 3, 'gust': 4.47, 'speed': 2.24}}
# 38.5167 -28.7
# Processing Record 45 of Set 1 | ytyk-kyuyel'
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 46 of Set 1 | stanley
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 54.868, 'lon': -1.6985},
#  'dt': 1681949027,
#  'id': 8224783,
#  'main': {'feels_like': 276.11,
#           'humidity': 94,
#           'pressure': 1031,
#           'temp': 277.85,
#           'temp_max': 279.2,
#           'temp_min': 276.16},
#  'name': 'Stanley',
#  'sys': {'country': 'GB',
#          'id': 2002060,
#          'sunrise': 1681966363,
#          'sunset': 1682018307,
#          'type': 2},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 40, 'speed': 2.06}}
# 54.868 -1.6985
# Processing Record 47 of Set 1 | kencong
# {'base': 'stations',
#  'clouds': {'all': 73},
#  'cod': 200,
#  'coord': {'lat': -8.2833, 'lon': 113.3667},
#  'dt': 1681949250,
#  'id': 1640354,
#  'main': {'feels_like': 299.62,
#           'grnd_level': 1007,
#           'humidity': 85,
#           'pressure': 1009,
#           'sea_level': 1009,
#           'temp': 298.78,
#           'temp_max': 298.78,
#           'temp_min': 298.78},
#  'name': 'Kencong',
#  'sys': {'country': 'ID', 'sunrise': 1681943318, 'sunset': 1681986128},
#  'timezone': 25200,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 51, 'gust': 1.08, 'speed': 0.95}}
# -8.2833 113.3667
# Processing Record 48 of Set 1 | kone
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -21.0595, 'lon': 164.8658},
#  'dt': 1681949201,
#  'id': 2140691,
#  'main': {'feels_like': 303.38,
#           'grnd_level': 1009,
#           'humidity': 63,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 301.42,
#           'temp_max': 301.42,
#           'temp_min': 301.42},
#  'name': 'Koné',
#  'sys': {'country': 'NC', 'sunrise': 1681931602, 'sunset': 1681973129},
#  'timezone': 39600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 200, 'gust': 0.97, 'speed': 1.02}}
# -21.0595 164.8658
# Processing Record 49 of Set 1 | nar'yan-mar
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 67.6713, 'lon': 53.087},
#  'dt': 1681949251,
#  'id': 523392,
#  'main': {'feels_like': 267.67,
#           'grnd_level': 1014,
#           'humidity': 97,
#           'pressure': 1014,
#           'sea_level': 1014,
#           'temp': 273.06,
#           'temp_max': 273.06,
#           'temp_min': 273.06},
#  'name': 'Naryan-Mar',
#  'snow': {'1h': 0.19},
#  'sys': {'country': 'RU', 'sunrise': 1681949937, 'sunset': 1682008440},
#  'timezone': 10800,
#  'visibility': 899,
#  'weather': [{'description': 'light snow',
#               'icon': '13n',
#               'id': 600,
#               'main': 'Snow'}],
#  'wind': {'deg': 252, 'gust': 10.4, 'speed': 5.83}}
# 67.6713 53.087
# Processing Record 50 of Set 1 | tazacorte
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 28.629, 'lon': -17.9293},
#  'dt': 1681949252,
#  'id': 6534196,
#  'main': {'feels_like': 291.1,
#           'humidity': 86,
#           'pressure': 1016,
#           'temp': 291.01,
#           'temp_max': 292.69,
#           'temp_min': 291.01},
#  'name': 'Tazacorte',
#  'sys': {'country': 'ES',
#          'id': 2002582,
#          'sunrise': 1681972876,
#          'sunset': 1682019584,
#          'type': 2},
#  'timezone': 3600,
#  'visibility': 8000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 20, 'speed': 2.57}}
# 28.629 -17.9293
# Processing Record 0 of Set 2 | codrington
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': -38.2667, 'lon': 141.9667},
#  'dt': 1681949065,
#  'id': 2171099,
#  'main': {'feels_like': 287.31,
#           'grnd_level': 1024,
#           'humidity': 75,
#           'pressure': 1026,
#           'sea_level': 1026,
#           'temp': 287.83,
#           'temp_max': 287.83,
#           'temp_min': 287.83},
#  'name': 'Codrington',
#  'sys': {'country': 'AU', 'sunrise': 1681938170, 'sunset': 1681977550},
#  'timezone': 36000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 301, 'gust': 6.35, 'speed': 4.26}}
# -38.2667 141.9667
# Processing Record 1 of Set 2 | codajas
# {'base': 'stations',
#  'clouds': {'all': 99},
#  'cod': 200,
#  'coord': {'lat': -3.8367, 'lon': -62.0569},
#  'dt': 1681948996,
#  'id': 3664525,
#  'main': {'feels_like': 299.09,
#           'grnd_level': 1006,
#           'humidity': 90,
#           'pressure': 1009,
#           'sea_level': 1009,
#           'temp': 298.18,
#           'temp_max': 298.18,
#           'temp_min': 298.18},
#  'name': 'Codajás',
#  'sys': {'country': 'BR', 'sunrise': 1681898809, 'sunset': 1681942053},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 80, 'gust': 1.65, 'speed': 1.29}}
# -3.8367 -62.0569
# Processing Record 2 of Set 2 | dhromolaxia
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 34.8755, 'lon': 33.5868},
#  'dt': 1681949118,
#  'id': 146654,
#  'main': {'feels_like': 290.98,
#           'humidity': 88,
#           'pressure': 1008,
#           'temp': 290.86,
#           'temp_max': 290.96,
#           'temp_min': 289.81},
#  'name': 'Dhromolaxia',
#  'sys': {'country': 'CY',
#          'id': 6372,
#          'sunrise': 1681960082,
#          'sunset': 1682007654,
#          'type': 1},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 300, 'speed': 6.69}}
# 34.8755 33.5868
# Processing Record 3 of Set 2 | talcahuano
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -36.7167, 'lon': -73.1167},
#  'dt': 1681949255,
#  'id': 3870282,
#  'main': {'feels_like': 287.81,
#           'humidity': 88,
#           'pressure': 1012,
#           'temp': 287.97,
#           'temp_max': 287.97,
#           'temp_min': 287.97},
#  'name': 'Talcahuano',
#  'sys': {'country': 'CL',
#          'id': 8499,
#          'sunrise': 1681903256,
#          'sunset': 1681942915,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 160, 'speed': 1.54}}
# -36.7167 -73.1167
# Processing Record 4 of Set 2 | hawaiian paradise park
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 19.5933, 'lon': -154.9731},
#  'dt': 1681949117,
#  'id': 5855809,
#  'main': {'feels_like': 298.08,
#           'humidity': 90,
#           'pressure': 1010,
#           'temp': 297.26,
#           'temp_max': 299.76,
#           'temp_min': 296.89},
#  'name': 'Hawaiian Paradise Park',
#  'sys': {'country': 'US',
#          'id': 2079676,
#          'sunrise': 1681919940,
#          'sunset': 1681965516,
#          'type': 2},
#  'timezone': -36000,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 160, 'gust': 12.86, 'speed': 6.69}}
# 19.5933 -154.9731
# Processing Record 5 of Set 2 | albany
# {'base': 'stations',
#  'clouds': {'all': 93},
#  'cod': 200,
#  'coord': {'lat': 42.6001, 'lon': -73.9662},
#  'dt': 1681948669,
#  'id': 5106841,
#  'main': {'feels_like': 273.51,
#           'humidity': 69,
#           'pressure': 1018,
#           'temp': 276.85,
#           'temp_max': 277.8,
#           'temp_min': 275.67},
#  'name': 'Albany',
#  'sys': {'country': 'US',
#          'id': 19530,
#          'sunrise': 1681898905,
#          'sunset': 1681947674,
#          'type': 2},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 306, 'gust': 9.14, 'speed': 3.84}}
# 42.6001 -73.9662
# Processing Record 6 of Set 2 | palompon
# {'base': 'stations',
#  'clouds': {'all': 77},
#  'cod': 200,
#  'coord': {'lat': 11.0508, 'lon': 124.3843},
#  'dt': 1681949256,
#  'id': 1696017,
#  'main': {'feels_like': 305.49,
#           'grnd_level': 1008,
#           'humidity': 72,
#           'pressure': 1009,
#           'sea_level': 1009,
#           'temp': 301.81,
#           'temp_max': 301.81,
#           'temp_min': 301.81},
#  'name': 'Palompon',
#  'sys': {'country': 'PH', 'sunrise': 1681939736, 'sunset': 1681984423},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 108, 'gust': 2.12, 'speed': 1.59}}
# 11.0508 124.3843
# Processing Record 7 of Set 2 | aykhal
# {'base': 'stations',
#  'clouds': {'all': 99},
#  'cod': 200,
#  'coord': {'lat': 66, 'lon': 111.5},
#  'dt': 1681949257,
#  'id': 2027296,
#  'main': {'feels_like': 258.09,
#           'grnd_level': 959,
#           'humidity': 96,
#           'pressure': 1018,
#           'sea_level': 1018,
#           'temp': 262.65,
#           'temp_max': 262.65,
#           'temp_min': 262.65},
#  'name': 'Aykhal',
#  'sys': {'country': 'RU', 'sunrise': 1681936602, 'sunset': 1681993740},
#  'timezone': 32400,
#  'visibility': 7813,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 346, 'gust': 2.61, 'speed': 2.23}}
# 66 111.5
# Processing Record 8 of Set 2 | sassandra
# {'base': 'stations',
#  'clouds': {'all': 97},
#  'cod': 200,
#  'coord': {'lat': 4.95, 'lon': -6.0833},
#  'dt': 1681949257,
#  'id': 2281951,
#  'main': {'feels_like': 299.32,
#           'grnd_level': 1009,
#           'humidity': 90,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 299.32,
#           'temp_max': 299.32,
#           'temp_min': 299.32},
#  'name': 'Sassandra',
#  'sys': {'country': 'CI', 'sunrise': 1681971342, 'sunset': 1682015432},
#  'timezone': 0,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 233, 'gust': 4.73, 'speed': 2.46}}
# 4.95 -6.0833
# Processing Record 9 of Set 2 | hovd
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 48.0056, 'lon': 91.6419},
#  'dt': 1681949194,
#  'id': 1516048,
#  'main': {'feels_like': 265.51,
#           'grnd_level': 863,
#           'humidity': 31,
#           'pressure': 1026,
#           'sea_level': 1026,
#           'temp': 270.07,
#           'temp_max': 270.07,
#           'temp_min': 270.07},
#  'name': 'Khovd',
#  'sys': {'country': 'MN', 'sunrise': 1681944939, 'sunset': 1681994934},
#  'timezone': 25200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 240, 'gust': 5.08, 'speed': 3.48}}
# 48.0056 91.6419
# Processing Record 10 of Set 2 | jamestown
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 42.097, 'lon': -79.2353},
#  'dt': 1681948981,
#  'id': 5122534,
#  'main': {'feels_like': 277.13,
#           'humidity': 61,
#           'pressure': 1020,
#           'temp': 279.93,
#           'temp_max': 279.95,
#           'temp_min': 277.35},
#  'name': 'Jamestown',
#  'sys': {'country': 'US',
#          'id': 4588,
#          'sunrise': 1681900214,
#          'sunset': 1681948893,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 360, 'speed': 4.12}}
# 42.097 -79.2353
# Processing Record 11 of Set 2 | oroqen zizhiqi
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 50.5667, 'lon': 123.7167},
#  'dt': 1681949258,
#  'id': 2038665,
#  'main': {'feels_like': 267.72,
#           'grnd_level': 945,
#           'humidity': 87,
#           'pressure': 996,
#           'sea_level': 996,
#           'temp': 272.42,
#           'temp_max': 272.42,
#           'temp_min': 272.42},
#  'name': 'Alihe',
#  'snow': {'1h': 0.6},
#  'sys': {'country': 'CN', 'sunrise': 1681936936, 'sunset': 1681987544},
#  'timezone': 28800,
#  'visibility': 3861,
#  'weather': [{'description': 'snow', 'icon': '13d', 'id': 601, 'main': 'Snow'}],
#  'wind': {'deg': 21, 'gust': 8.06, 'speed': 4.37}}
# 50.5667 123.7167
# Processing Record 12 of Set 2 | yuktae-dong
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 40.0247, 'lon': 128.1597},
#  'dt': 1681949259,
#  'id': 2038854,
#  'main': {'feels_like': 285.44,
#           'grnd_level': 1003,
#           'humidity': 64,
#           'pressure': 1003,
#           'sea_level': 1003,
#           'temp': 286.39,
#           'temp_max': 286.39,
#           'temp_min': 286.39},
#  'name': 'Yuktae-dong',
#  'sys': {'country': 'KP', 'sunrise': 1681936987, 'sunset': 1681985360},
#  'timezone': 32400,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 246, 'gust': 7.55, 'speed': 5.37}}
# 40.0247 128.1597
# Processing Record 13 of Set 2 | linxia chengguanzhen
# {'base': 'stations',
#  'clouds': {'all': 29},
#  'cod': 200,
#  'coord': {'lat': 35.6003, 'lon': 103.2064},
#  'dt': 1681949259,
#  'id': 1803331,
#  'main': {'feels_like': 280.58,
#           'grnd_level': 811,
#           'humidity': 32,
#           'pressure': 1015,
#           'sea_level': 1015,
#           'temp': 281.07,
#           'temp_max': 281.07,
#           'temp_min': 281.07},
#  'name': 'Linxia Chengguanzhen',
#  'sys': {'country': 'CN', 'sunrise': 1681943332, 'sunset': 1681990991},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 336, 'gust': 1.78, 'speed': 1.37}}
# 35.6003 103.2064
# Processing Record 14 of Set 2 | touros
# {'base': 'stations',
#  'clouds': {'all': 97},
#  'cod': 200,
#  'coord': {'lat': -5.1989, 'lon': -35.4608},
#  'dt': 1681949260,
#  'id': 3386213,
#  'main': {'feels_like': 299.49,
#           'grnd_level': 1011,
#           'humidity': 83,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 299.49,
#           'temp_max': 299.49,
#           'temp_min': 299.49},
#  'name': 'Touros',
#  'sys': {'country': 'BR', 'sunrise': 1681892491, 'sunset': 1681935608},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 109, 'gust': 7.01, 'speed': 4.14}}
# -5.1989 -35.4608
# Processing Record 15 of Set 2 | puerto san carlos
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 16 of Set 2 | squamish
# {'base': 'stations',
#  'clouds': {'all': 97},
#  'cod': 200,
#  'coord': {'lat': 49.7014, 'lon': -123.1512},
#  'dt': 1681949261,
#  'id': 5907106,
#  'main': {'feels_like': 280.66,
#           'humidity': 67,
#           'pressure': 1020,
#           'temp': 282.58,
#           'temp_max': 284.66,
#           'temp_min': 282.51},
#  'name': 'Squamish',
#  'sys': {'country': 'CA',
#          'id': 2005198,
#          'sunrise': 1681909931,
#          'sunset': 1681960252,
#          'type': 2},
#  'timezone': -25200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 68, 'gust': 3.58, 'speed': 3.58}}
# 49.7014 -123.1512
# Processing Record 17 of Set 2 | atafu village
# {'base': 'stations',
#  'clouds': {'all': 96},
#  'cod': 200,
#  'coord': {'lat': -8.5421, 'lon': -172.5159},
#  'dt': 1681949047,
#  'id': 7522183,
#  'main': {'feels_like': 304.38,
#           'grnd_level': 1009,
#           'humidity': 69,
#           'pressure': 1009,
#           'sea_level': 1009,
#           'temp': 301.51,
#           'temp_max': 301.51,
#           'temp_min': 301.51},
# ...
#           'temp': 298.37,
#           'temp_max': 299.35,
#           'temp_min': 297.5},
#  'name': 'San Patricio',
#  'sys': {'country': 'US',
#          'id': 2040001,
#          'sunrise': 1681905663,
#          'sunset': 1681952218,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 141, 'gust': 9.52, 'speed': 6.66}}
# 28.017 -97.5169
# Processing Record 34 of Set 12 | bilmak
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': 47.3624, 'lon': 36.6511},
#  'dt': 1681949573,
#  'id': 703494,
#  'main': {'feels_like': 279.91,
#           'grnd_level': 984,
#           'humidity': 97,
#           'pressure': 1009,
#           'sea_level': 1009,
#           'temp': 282.12,
#           'temp_max': 282.12,
#           'temp_min': 282.12},
#  'name': 'Bilmak',
#  'rain': {'1h': 0.16},
#  'sys': {'country': 'UA', 'sunrise': 1681958194, 'sunset': 1682008070},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 127, 'gust': 8.63, 'speed': 3.96}}
# 47.3624 36.6511
# Processing Record 35 of Set 12 | miquelon
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 47.0975, 'lon': -56.3814},
#  'dt': 1681949574,
#  'id': 3424941,
#  'main': {'feels_like': 268.33,
#           'grnd_level': 1016,
#           'humidity': 96,
#           'pressure': 1016,
#           'sea_level': 1016,
#           'temp': 274.15,
#           'temp_max': 274.15,
#           'temp_min': 274.15},
#  'name': 'Miquelon',
#  'sys': {'country': 'PM',
#          'id': 6582,
#          'sunrise': 1681894232,
#          'sunset': 1681943906,
#          'type': 1},
#  'timezone': -7200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 111, 'gust': 9.8, 'speed': 7.46}}
# 47.0975 -56.3814
# Processing Record 36 of Set 12 | cidade velha
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 14.9167, 'lon': -23.6167},
#  'dt': 1681949076,
#  'id': 3374725,
#  'main': {'feels_like': 296.7,
#           'humidity': 73,
#           'pressure': 1016,
#           'temp': 296.41,
#           'temp_max': 296.41,
#           'temp_min': 296.41},
#  'name': 'Cidade Velha',
#  'sys': {'country': 'CV',
#          'id': 2462,
#          'sunrise': 1681888678,
#          'sunset': 1681933736,
#          'type': 1},
#  'timezone': -3600,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 30, 'speed': 7.2}}
# 14.9167 -23.6167
# Processing Record 37 of Set 12 | rokycany
# {'base': 'stations',
#  'clouds': {'all': 9},
#  'cod': 200,
#  'coord': {'lat': 49.7427, 'lon': 13.5946},
#  'dt': 1681949575,
#  'id': 3066794,
#  'main': {'feels_like': 267.07,
#           'humidity': 95,
#           'pressure': 1013,
#           'temp': 274.07,
#           'temp_max': 277.03,
#           'temp_min': 273.21},
#  'name': 'Rokycany',
#  'sys': {'country': 'CZ',
#          'id': 2029820,
#          'sunrise': 1681963434,
#          'sunset': 1682013896,
#          'type': 2},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 90, 'speed': 25.03}}
# 49.7427 13.5946
# Processing Record 38 of Set 12 | san lawrenz
# {'base': 'stations',
#  'clouds': {'all': 56},
#  'cod': 200,
#  'coord': {'lat': 36.0553, 'lon': 14.204},
#  'dt': 1681949575,
#  'id': 2562619,
#  'main': {'feels_like': 288.88,
#           'humidity': 78,
#           'pressure': 1012,
#           'temp': 289.18,
#           'temp_max': 289.18,
#           'temp_min': 287.82},
#  'name': 'Saint Lawrence',
#  'rain': {'1h': 0.22},
#  'sys': {'country': 'MT',
#          'id': 2005262,
#          'sunrise': 1681964639,
#          'sunset': 1682012399,
#          'type': 2},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 134, 'gust': 4.02, 'speed': 0.89}}
# 36.0553 14.204
# Processing Record 39 of Set 12 | prince rupert
# {'base': 'stations',
#  'clouds': {'all': 95},
#  'cod': 200,
#  'coord': {'lat': 54.3161, 'lon': -130.3201},
#  'dt': 1681949575,
#  'id': 6113406,
#  'main': {'feels_like': 279.98,
#           'grnd_level': 1014,
#           'humidity': 64,
#           'pressure': 1017,
#           'sea_level': 1017,
#           'temp': 281.84,
#           'temp_max': 281.84,
#           'temp_min': 281.84},
#  'name': 'Prince Rupert',
#  'rain': {'1h': 0.18},
#  'sys': {'country': 'CA', 'sunrise': 1681911010, 'sunset': 1681962614},
#  'timezone': -25200,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 207, 'gust': 4.66, 'speed': 3.18}}
# 54.3161 -130.3201
# Processing Record 40 of Set 12 | tolanaro
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -25.0319, 'lon': 46.9987},
#  'dt': 1681949162,
#  'id': 1055433,
#  'main': {'feels_like': 297,
#           'humidity': 94,
#           'pressure': 1015,
#           'temp': 296.19,
#           'temp_max': 296.19,
#           'temp_min': 296.19},
#  'name': 'Tôlanaro',
#  'sys': {'country': 'MG',
#          'id': 2147,
#          'sunrise': 1681960117,
#          'sunset': 1682001181,
#          'type': 1},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 100, 'speed': 3.09}}
# -25.0319 46.9987
# Processing Record 41 of Set 12 | sakiai
# {'base': 'stations',
#  'clouds': {'all': 70},
#  'cod': 200,
#  'coord': {'lat': 54.9547, 'lon': 23.0358},
#  'dt': 1681949576,
#  'id': 595044,
#  'main': {'feels_like': 278.26,
#           'grnd_level': 1018,
#           'humidity': 84,
#           'pressure': 1024,
#           'sea_level': 1024,
#           'temp': 281.46,
#           'temp_max': 281.46,
#           'temp_min': 281.46},
#  'name': 'Šakiai',
#  'sys': {'country': 'LT', 'sunrise': 1681960422, 'sunset': 1682012377},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 60, 'gust': 13.18, 'speed': 5.96}}
# 54.9547 23.0358
# Processing Record 42 of Set 12 | barra do bugres
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -15.0725, 'lon': -57.1811},
#  'dt': 1681949084,
#  'id': 3470718,
#  'main': {'feels_like': 296.86,
#           'grnd_level': 992,
#           'humidity': 97,
#           'pressure': 1013,
#           'sea_level': 1013,
#           'temp': 295.99,
#           'temp_max': 295.99,
#           'temp_min': 295.99},
#  'name': 'Barra do Bugres',
#  'rain': {'1h': 0.18},
#  'sys': {'country': 'BR', 'sunrise': 1681898179, 'sunset': 1681940343},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 177, 'gust': 1.57, 'speed': 0.94}}
# -15.0725 -57.1811
# Processing Record 43 of Set 12 | nema
# {'base': 'stations',
#  'clouds': {'all': 6},
#  'cod': 200,
#  'coord': {'lat': 57.5067, 'lon': 50.5011},
#  'dt': 1681949577,
#  'id': 522745,
#  'main': {'feels_like': 274.57,
#           'grnd_level': 1008,
#           'humidity': 92,
#           'pressure': 1026,
#           'sea_level': 1026,
#           'temp': 276.08,
#           'temp_max': 276.08,
#           'temp_min': 276.08},
#  'name': 'Nema',
#  'sys': {'country': 'RU', 'sunrise': 1681953393, 'sunset': 1682006224},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 64, 'gust': 1.6, 'speed': 1.62}}
# 57.5067 50.5011
# Processing Record 44 of Set 12 | sovetskiy
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': 61.3614, 'lon': 63.5842},
#  'dt': 1681949578,
#  'id': 1491230,
#  'main': {'feels_like': 264.68,
#           'grnd_level': 1011,
#           'humidity': 90,
#           'pressure': 1025,
#           'sea_level': 1025,
#           'temp': 268.19,
#           'temp_max': 268.19,
#           'temp_min': 268.19},
#  'name': 'Sovetskiy',
#  'sys': {'country': 'RU', 'sunrise': 1681949433, 'sunset': 1682003905},
#  'timezone': 18000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 227, 'gust': 6.53, 'speed': 2.17}}
# 61.3614 63.5842
# Processing Record 45 of Set 12 | caldas novas
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -17.7417, 'lon': -48.625},
#  'dt': 1681949578,
#  'id': 3468100,
#  'main': {'feels_like': 294.32,
#           'grnd_level': 936,
#           'humidity': 94,
#           'pressure': 1014,
#           'sea_level': 1014,
#           'temp': 293.75,
#           'temp_max': 293.75,
#           'temp_min': 293.75},
#  'name': 'Caldas Novas',
#  'sys': {'country': 'BR', 'sunrise': 1681896259, 'sunset': 1681938157},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 230, 'gust': 1.46, 'speed': 1.42}}
# -17.7417 -48.625
# Processing Record 46 of Set 12 | san juan de miraflores
# {'base': 'stations',
#  'clouds': {'all': 59},
#  'cod': 200,
#  'coord': {'lat': -12.1629, 'lon': -76.9635},
#  'dt': 1681949579,
#  'id': 3936456,
#  'main': {'feels_like': 298.16,
#           'humidity': 75,
#           'pressure': 984,
#           'temp': 297.69,
#           'temp_max': 297.69,
#           'temp_min': 296.44},
#  'name': 'San Juan de Miraflores',
#  'sys': {'country': 'PE',
#          'id': 2037860,
#          'sunrise': 1681902784,
#          'sunset': 1681945232,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 155, 'gust': 3.74, 'speed': 3.74}}
# -12.1629 -76.9635
# Processing Record 47 of Set 12 | kurtamysh
# {'base': 'stations',
#  'clouds': {'all': 18},
#  'cod': 200,
#  'coord': {'lat': 54.9103, 'lon': 64.4319},
#  'dt': 1681949579,
#  'id': 1501255,
#  'main': {'feels_like': 269.94,
#           'grnd_level': 1018,
#           'humidity': 53,
#           'pressure': 1031,
#           'sea_level': 1031,
#           'temp': 273.74,
#           'temp_max': 273.74,
#           'temp_min': 273.74},
#  'name': 'Kurtamysh',
#  'sys': {'country': 'RU', 'sunrise': 1681950511, 'sunset': 1682002421},
#  'timezone': 18000,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 170, 'gust': 7.85, 'speed': 3.51}}
# 54.9103 64.4319
# Processing Record 48 of Set 12 | xining
# {'base': 'stations',
#  'clouds': {'all': 61},
#  'cod': 200,
#  'coord': {'lat': 36.6167, 'lon': 101.7667},
#  'dt': 1681949580,
#  'id': 1788852,
#  'main': {'feels_like': 275.93,
#           'grnd_level': 773,
#           'humidity': 40,
#           'pressure': 1014,
#           'sea_level': 1014,
#           'temp': 277.68,
#           'temp_max': 277.68,
#           'temp_min': 277.68},
#  'name': 'Xining',
#  'sys': {'country': 'CN', 'sunrise': 1681943598, 'sunset': 1681991416},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 127, 'gust': 4.94, 'speed': 2.04}}
# 36.6167 101.7667
# Processing Record 49 of Set 12 | ambasa
# {'base': 'stations',
#  'clouds': {'all': 41},
#  'cod': 200,
#  'coord': {'lat': 23.9172, 'lon': 91.8472},
#  'dt': 1681949580,
#  'id': 1278842,
#  'main': {'feels_like': 298.44,
#           'grnd_level': 993,
#           'humidity': 89,
#           'pressure': 1004,
#           'sea_level': 1004,
#           'temp': 297.61,
#           'temp_max': 297.61,
#           'temp_min': 297.61},
#  'name': 'Āmbāsa',
#  'sys': {'country': 'IN', 'sunrise': 1681946841, 'sunset': 1681992933},
#  'timezone': 19800,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 179, 'gust': 6.72, 'speed': 2.22}}
# 23.9172 91.8472
# Processing Record 0 of Set 13 | blama
# {'base': 'stations',
#  'clouds': {'all': 27},
#  'cod': 200,
#  'coord': {'lat': 7.8736, 'lon': -11.3433},
#  'dt': 1681949581,
#  'id': 2410065,
#  'main': {'feels_like': 299.68,
#           'grnd_level': 998,
#           'humidity': 86,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 298.81,
#           'temp_max': 298.81,
#           'temp_min': 298.81},
#  'name': 'Blama',
#  'sys': {'country': 'SL', 'sunrise': 1681972460, 'sunset': 1682016839},
#  'timezone': 0,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 188, 'gust': 2.57, 'speed': 0.94}}
# 7.8736 -11.3433
# Processing Record 1 of Set 13 | hihifo
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 2 of Set 13 | sonsorol village
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 3 of Set 13 | antequera
# {'base': 'stations',
#  'clouds': {'all': 98},
#  'cod': 200,
#  'coord': {'lat': 37.0194, 'lon': -4.5612},
#  'dt': 1681949582,
#  'id': 2521710,
#  'main': {'feels_like': 285.47,
#           'grnd_level': 954,
#           'humidity': 88,
#           'pressure': 1015,
#           'sea_level': 1015,
#           'temp': 285.85,
#           'temp_max': 286.45,
#           'temp_min': 283.4},
#  'name': 'Antequera',
#  'sys': {'country': 'ES',
#          'id': 2010336,
#          'sunrise': 1681969062,
#          'sunset': 1682016982,
#          'type': 2},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 161, 'gust': 2.02, 'speed': 2.13}}
# 37.0194 -4.5612
# Processing Record 4 of Set 13 | saudarkrokur
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 65.7461, 'lon': -19.6394},
#  'dt': 1681949584,
#  'id': 2627309,
#  'main': {'feels_like': 278.61,
#           'grnd_level': 1030,
#           'humidity': 83,
#           'pressure': 1031,
#           'sea_level': 1031,
#           'temp': 281.69,
#           'temp_max': 281.69,
#           'temp_min': 281.69},
#  'name': 'Sauðarkrokur',
#  'sys': {'country': 'IS', 'sunrise': 1681968080, 'sunset': 1682025200},
#  'timezone': 0,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 172, 'gust': 9.09, 'speed': 5.81}}
# 65.7461 -19.6394
# Processing Record 5 of Set 13 | broken hill
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -31.95, 'lon': 141.4333},
#  'dt': 1681949584,
#  'id': 2173911,
#  'main': {'feels_like': 285.9,
#           'grnd_level': 990,
#           'humidity': 52,
#           'pressure': 1027,
#           'sea_level': 1027,
#           'temp': 287.09,
#           'temp_max': 287.09,
#           'temp_min': 287.09},
#  'name': 'Broken Hill',
#  'sys': {'country': 'AU', 'sunrise': 1681937862, 'sunset': 1681978115},
#  'timezone': 34200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 150, 'gust': 10.08, 'speed': 7.9}}
# -31.95 141.4333
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# done
# Convert the cities weather data into a Pandas DataFrame
city_data_df=pd.DataFrame(
    city_data
)

# Show Record Count
city_data_df.count()
# Out:
# City          579
# Lat           579
# Lng           579
# Max Temp      579
# Humidity      579
# Cloudiness    579
# Wind Speed    579
# Country       579
# Date          579
# dtype: int64

# %%
# done
# Display sample data
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  chhota udepur  22.3167   74.0167    300.25        32          30
# 1        rosarno  38.4841   15.9790    286.71        72          37
# 2      grytviken -54.2811  -36.5092    276.82        95         100
# 3       waitangi -43.9535 -176.5597    290.83        89          94
# 4      adamstown -25.0660 -130.1015    297.56        76          96
#
#    Wind Speed Country        Date
# 0        1.27      IN  1681949220
# 1        2.32      IT  1681949220
# 2        1.70      GS  1681949016
# 3        4.02      NZ  1681949012
# 4        0.87      PN  1681949007

# %%
# done
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# done
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        chhota udepur  22.3167   74.0167    300.25        32          30
# 1              rosarno  38.4841   15.9790    286.71        72          37
# 2            grytviken -54.2811  -36.5092    276.82        95         100
# 3             waitangi -43.9535 -176.5597    290.83        89          94
# 4            adamstown -25.0660 -130.1015    297.56        76          96
#
#          Wind Speed Country        Date
# City_ID
# 0              1.27      IN  1681949220
# 1              2.32      IT  1681949220
# 2              1.70      GS  1681949016
# 3              4.02      NZ  1681949012
# 4              0.87      PN  1681949007

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# done
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'],city_data_df['Max Temp'])

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.title('Latitude')


# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# done
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'],city_data_df['Humidity'])

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title("Latitude v. Humidity")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# done
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'],city_data_df['Cloudiness'])

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title("Latitude v. Cloudiness")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# done
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'],city_data_df['Wind Speed'])

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title("Latitude v. Wind Speed")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# done
# Define a function to create Linear Regression plots
def lr(x,y):
    result=linregress(x,y)
#     print(result)
    return result

# %%
# done
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        chhota udepur  22.3167   74.0167    300.25        32          30
# 1              rosarno  38.4841   15.9790    286.71        72          37
# 2            grytviken -54.2811  -36.5092    276.82        95         100
# 3             waitangi -43.9535 -176.5597    290.83        89          94
# 4            adamstown -25.0660 -130.1015    297.56        76          96
#
#          Wind Speed Country        Date
# City_ID
# 0              1.27      IN  1681949220
# 1              2.32      IT  1681949220
# 2              1.70      GS  1681949016
# 3              4.02      NZ  1681949012
# 4              0.87      PN  1681949007

# %%
# done
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df=city_data_df[city_data_df['Lat']>=0]
# Display sample data
northern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        chhota udepur  22.3167   74.0167    300.25        32          30
# 1              rosarno  38.4841   15.9790    286.71        72          37
# 5            santa ana  33.7456 -117.8678    296.15        47          20
# 7              salinas  36.6777 -121.6555    293.14        56           0
# 8           greenville  35.6127  -77.3663    296.55        50           0
#
#          Wind Speed Country        Date
# City_ID
# 0              1.27      IN  1681949220
# 1              2.32      IT  1681949220
# 5              6.17      US  1681949215
# 7              6.17      US  1681949166
# 8              0.00      US  1681949224

# %%
# done
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df=city_data_df[city_data_df['Lat']<0]
# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2                grytviken -54.2811  -36.5092    276.82        95         100
# 3                 waitangi -43.9535 -176.5597    290.83        89          94
# 4                adamstown -25.0660 -130.1015    297.56        76          96
# 6             puerto aysen -45.4000  -72.7000    285.64        99         100
# 9        port-aux-francais -49.3500   70.2167    277.98        68          18
#
#          Wind Speed Country        Date
# City_ID
# 2              1.70      GS  1681949016
# 3              4.02      NZ  1681949012
# 4              0.87      PN  1681949007
# 6              1.98      CL  1681949223
# 9             15.50      TF  1681948984

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
lrnh_tvl=lr(northern_hemi_df['Lat'],northern_hemi_df['Max Temp'])
print(lrnh_tvl)
northern_hemi_df['predict temp given lat']=lrnh_tvl[1]+northern_hemi_df.loc[:,'Lat']*lrnh_tvl[0]
plt.scatter(northern_hemi_df['Lat'],northern_hemi_df['Max Temp'])
plt.plot(northern_hemi_df['Lat'],northern_hemi_df['predict temp given lat'],color='red')
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.title("Temperature v. Latitude")
# Out:
# LinregressResult(slope=-0.5396170828191988, intercept=306.1339374610204, rvalue=-0.8727131187689188, pvalue=6.287762264668874e-127, stderr=0.015075420968789577, intercept_stderr=0.6264002258026016)
# LinregressResult(slope=-0.5396170828191988, intercept=306.1339374610204, rvalue=-0.8727131187689188, pvalue=6.287762264668874e-127, stderr=0.015075420968789577, intercept_stderr=0.6264002258026016)
# C:\Users\rober\AppData\Local\Temp\ipykernel_10768\3796633818.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   northern_hemi_df['predict temp given lat']=lrnh_tvl[1]+northern_hemi_df.loc[:,'Lat']*lrnh_tvl[0]
# Text(0.5, 1.0, 'Temperature v. Latitude')

# %%
# Linear regression on Southern Hemisphere
lrsh_tvl=lr(southern_hemi_df['Lat'],southern_hemi_df['Max Temp'])
print(lrsh_tvl)
southern_hemi_df['predict temp given lat']=lrsh_tvl[1]+southern_hemi_df.loc[:,'Lat']*lrsh_tvl[0]
plt.scatter(southern_hemi_df['Lat'],southern_hemi_df['Max Temp'])
plt.plot(southern_hemi_df['Lat'],southern_hemi_df['predict temp given lat'],color='red')
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.title("Temperature v. Latitude")
# Out:
# LinregressResult(slope=0.3114685250779405, intercept=301.0270082936654, rvalue=0.7406910625096184, pvalue=7.150001994847723e-32, stderr=0.0214176605165528, intercept_stderr=0.5573487111282504)
# C:\Users\rober\AppData\Local\Temp\ipykernel_10768\2162813672.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   southern_hemi_df['predict temp given lat']=lrsh_tvl[1]+southern_hemi_df.loc[:,'Lat']*lrsh_tvl[0]
# Text(0.5, 1.0, 'Temperature v. Latitude')

# %% [markdown]
# **Discussion about the linear relationship:** The relationship to be analyzed is temperature v latitude.  Linear regression in the northern hemisphere has a negative slope of -0.53, while the slope of the southern hemisphere is 0.31, a positive slope.  This seems to be expected because the hemispheres mirror each other.  The r values are pretty good, -0.87 and 0.74 respectively, so the linear regression indicates the variables are highly coordinated. The pvalues are both very small:  this indicates that the relationship is highly significant.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lrnh_hvl=lr(northern_hemi_df['Lat'],northern_hemi_df['Humidity'])
print(lrnh_hvl)
northern_hemi_df['predict hum given lat']=lrnh_hvl[1]+northern_hemi_df.loc[:,'Lat']*lrnh_hvl[0]
plt.scatter(northern_hemi_df['Lat'],northern_hemi_df['Humidity'])
plt.plot(northern_hemi_df['Lat'],northern_hemi_df['predict hum given lat'],color='red')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title("Humidity v. Latitude")
# Out:
# LinregressResult(slope=0.16061734064506628, intercept=63.73723819283764, rvalue=0.13520361950295953, pvalue=0.006562726111733003, stderr=0.05877948027286255, intercept_stderr=2.4423516790481337)
# C:\Users\rober\AppData\Local\Temp\ipykernel_10768\3952238302.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   northern_hemi_df['predict hum given lat']=lrnh_hvl[1]+northern_hemi_df.loc[:,'Lat']*lrnh_hvl[0]
# Text(0.5, 1.0, 'Humidity v. Latitude')

# %%
# Southern Hemisphere
lrsh_hvl=lr(southern_hemi_df['Lat'],southern_hemi_df['Humidity'])
print(lrsh_hvl)
southern_hemi_df['predict hum given lat']=lrsh_hvl[1]+southern_hemi_df.loc[:,'Lat']*lrsh_hvl[0]
# northern_hemi_df.head()
plt.scatter(southern_hemi_df['Lat'],southern_hemi_df['Humidity'])
plt.plot(southern_hemi_df['Lat'],southern_hemi_df['predict hum given lat'],color='red')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title("Humidity v. Latitude")
# Out:
# LinregressResult(slope=0.3070441605972765, intercept=82.40549587790298, rvalue=0.25114667543645963, pvalue=0.0007733867320198914, stderr=0.08971215288445436, intercept_stderr=2.3345665015115715)
# C:\Users\rober\AppData\Local\Temp\ipykernel_10768\37014751.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   southern_hemi_df['predict hum given lat']=lrsh_hvl[1]+southern_hemi_df.loc[:,'Lat']*lrsh_hvl[0]
# Text(0.5, 1.0, 'Humidity v. Latitude')

# %% [markdown]
# **Discussion about the linear relationship:** The humidity v latitude relationshp for northern and southern hemispheres both have very low r-values:  0.13 and 0.25 respectively.  This is horrible.  That indicates that these relationships are not highly coordinated and the linear regression explains very little.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lrnh_cvl=lr(northern_hemi_df['Lat'],northern_hemi_df['Cloudiness'])
print(lrnh_cvl)
northern_hemi_df['predict cloudiness given lat']=lrnh_cvl[1]+northern_hemi_df.loc[:,'Lat']*lrnh_cvl[0]
plt.scatter(northern_hemi_df['Lat'],northern_hemi_df['Cloudiness'])
plt.plot(northern_hemi_df['Lat'],northern_hemi_df['predict cloudiness given lat'],color='red')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title("Cloudiness v. Latitude")
# Out:
# LinregressResult(slope=0.28038312321239717, intercept=48.06197193750705, rvalue=0.13836985682346314, pvalue=0.005393788687790074, stderr=0.10021675283191729, intercept_stderr=4.164115664370522)
# C:\Users\rober\AppData\Local\Temp\ipykernel_10768\1207330117.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   northern_hemi_df['predict cloudiness given lat']=lrnh_cvl[1]+northern_hemi_df.loc[:,'Lat']*lrnh_cvl[0]
# Text(0.5, 1.0, 'Cloudiness v. Latitude')

# %%
# Southern Hemisphere
lrsh_cvl=lr(southern_hemi_df['Lat'],southern_hemi_df['Cloudiness'])
print(lrsh_cvl)
southern_hemi_df['predict cloudiness given lat']=lrsh_cvl[1]+southern_hemi_df.loc[:,'Lat']*lrsh_cvl[0]
plt.scatter(southern_hemi_df['Lat'],southern_hemi_df['Cloudiness'])
plt.plot(southern_hemi_df['Lat'],southern_hemi_df['predict cloudiness given lat'],color='red')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title("Cloudiness v. Latitude")
# Out:
# LinregressResult(slope=0.43488080030295195, intercept=69.75269303263512, rvalue=0.16309463682696346, pvalue=0.030558121832946223, stderr=0.1994351169469788, intercept_stderr=5.189871475374428)
# C:\Users\rober\AppData\Local\Temp\ipykernel_10768\578084705.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   southern_hemi_df['predict cloudiness given lat']=lrsh_cvl[1]+southern_hemi_df.loc[:,'Lat']*lrsh_cvl[0]
# Text(0.5, 1.0, 'Cloudiness v. Latitude')

# %% [markdown]
# **Discussion about the linear relationship:** The linear regression of the relationship between cloudiness and latitude, by hemisphere, shows a very poor coorelation:  0.14 northern and 0.16 southern.  This is horrible.  There is so much variation unexplained by the linear regression that it is not useful.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lrnh_wvl=lr(northern_hemi_df['Lat'],northern_hemi_df['Wind Speed'])
print(lrnh_wvl)
northern_hemi_df['predict wind speed given lat']=lrnh_wvl[1]+northern_hemi_df.loc[:,'Lat']*lrnh_wvl[0]
plt.scatter(northern_hemi_df['Lat'],northern_hemi_df['Wind Speed'])
plt.plot(northern_hemi_df['Lat'],northern_hemi_df['predict wind speed given lat'],color='red')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title("Wind Speed v. Latitude")
# Out:
# LinregressResult(slope=0.0029215539349462345, intercept=3.5290639207127588, rvalue=0.020459371404678173, pvalue=0.6821829541887241, stderr=0.007129490946587101, intercept_stderr=0.29623814472879273)
# C:\Users\rober\AppData\Local\Temp\ipykernel_10768\3437519888.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   northern_hemi_df['predict wind speed given lat']=lrnh_wvl[1]+northern_hemi_df.loc[:,'Lat']*lrnh_wvl[0]
# Text(0.5, 1.0, 'Wind Speed v. Latitude')

# %%
# Southern Hemisphere
lrsh_wvl=lr(southern_hemi_df['Lat'],southern_hemi_df['Wind Speed'])
print(lrsh_wvl)
southern_hemi_df['predict wind speed given lat']=lrsh_wvl[1]+southern_hemi_df.loc[:,'Lat']*lrsh_wvl[0]
plt.scatter(southern_hemi_df['Lat'],southern_hemi_df['Wind Speed'])
plt.plot(southern_hemi_df['Lat'],southern_hemi_df['predict wind speed given lat'],color='red')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title("Wind Speed v. Latitude")
# Out:
# LinregressResult(slope=-0.04417203980063845, intercept=2.4275247250468244, rvalue=-0.2361785626336944, pvalue=0.001601121319045362, stderr=0.01377745118650842, intercept_stderr=0.35852863834022386)
# C:\Users\rober\AppData\Local\Temp\ipykernel_10768\2903003423.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   southern_hemi_df['predict wind speed given lat']=lrsh_wvl[1]+southern_hemi_df.loc[:,'Lat']*lrsh_wvl[0]
# Text(0.5, 1.0, 'Wind Speed v. Latitude')

# %% [markdown]
# **Discussion about the linear relationship:** Wind speed is poorly coorelated with latitude.  The northern hemisphere has, for the relationship, an r value of 0.02 and the southern hemisphere an r-value of 0.23. This means that the relationship is pretty horrible and doesn't explain much.  However, it is rather odd that the r-values between the northern and southern hemisphere vary greatly.  I don't know what could create that difference.
